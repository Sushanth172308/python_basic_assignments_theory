# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushanth172308/python_basic_assignments_theory/blob/main/Assignment_3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Why are functions advantageous to have in your programs?
#
# Answer:
# A. we don't have to  write the same logic over and over. we can bind the logic in  one function and call it at many places.we can also give different inputs while calling.
#
#
# B .It helps to divide the larger programs into small groups so that we can read the code and debug faster and better.
#
# C. Many persons can work on the same program by assinging different functions to each of them.
#
#
# ---
#
# 2. When does the code in a function run: when it's specified or when it's called?
#
# Answer:
#
#
# When it's called.
#
#
#
# ---
#  3. What statement creates a function?
#
#  Answer:
#
#  The function is created by using def keyword, followed by a name of our choice.
#
#
#
# ---
#
# 4. What is the difference between a function and a function call?
#
# Answer:
#
# A function is a code block that does a specific operation and produces out put. Generally accepts inputs as parameter(not mandatory) and returns a result.
#
#
# on the otherhand a function call is the code used to pass the control to a function
#
#
#
# ---
# 5. How many global scopes are there in a Python program? How many local scopes?
#
# Answer:
#
# A.Global scope: There is only one global scope per program execution. this scope exists until the program terminates.
#
# B Local scope: the variables we use in we use in  for every function  they will have their own  local scope  we can't access these variabales from global socpe.
#
#
#
# ---
#
#
#
# ---
#
#
#
#
# 6. What happens to variables in a local scope when the function call returns?
#
# Answer: When the fucntions returns , the local socpe is destroyed so these variable are forgotten.
#
#
#
#
# ---
#
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# Answer:
#
# Return value: Return values are values that a function  returns when it has completed. yes it is possible to have a return value in an expression.
#
#
#
# ---
#
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#
# Answer:
#
# A function with out an explicit return statement will return None.
#
#
#
#
# ---
#
# 9. How do you make a function variable refer to the global variable?
#
# Answer: We can make a function variable refer to global variable simply by using keyword global
#
#
#
# ---
#
# 10. What is the data type of None?
# Answer:
#
# None keyword is an object, and it is an data type of the class NoneType.
#
#
#
# ---
# 11. What does the sentence import areallyourpetsnamederic do?
# Answer:
#
# It imports the module called  areallyyourpetsnamederic if available.
#
#
#
# ---
#
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
# Answer:spam.bacon()
#
#
# ---
#
# 13. What can you do to save a programme from crashing if it encounters an error?
#
# Answer:
#
# In order to save the program form crashing i will handle the excetions by using
# try and except blocks.
#
#
#
# ---
#
#
#
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# Answer:
#
# <b>Try Clause:</b>
#  All the statemtns are executed until an excetion is encountered.
#
#
#  <b>except clause:</b>
#  This clause will catches and handles the exceptions which are encountered in try clause.
