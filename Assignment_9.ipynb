# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushanth172308/python_basic_assignments_theory/blob/main/Assignment_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. To what does a relative path refer?
#
# Answer:
#
# Relative path refers to current workikng directory
#
#
#
# ---
#
# 2. What does an absolute path start with your operating system?
#
# Answer: It begins with root folder.
# (Complete path from strat of actual file system directory).
#
#
#
# ---
#
#
# 3. What do the functions os.getcwd() and os.chdir() do?
#
# os.getcwd():
#
# Answer:
#
# os.getcwd()--> gets the current working directory as string value.
#
# os.Chdir()---> to change  current working directory to the argument.
#
#
#
#
# ---
#
#
# 4. What are the . and .. folders?
#
# Answer:
#
# The . is the current directory
#
# .. singifies the parent directory.
#
#
# ---
#
#
# 5. In C:\bacon\eggs\spam.txt, which part is the dir name, and which part is the base name?
#
#
# Answer:Dir name ->C:\bacon\eggs\
#
# base name->spam.txt
#
#
#
#
# ---
#
#
# 6. What are the three “mode” arguments that can be passed to the open() function?
#
# Answer:
#
# Read-->open('text.txt','r)
#
# write-->open('text.txt','w)
#
# append =open('text.txt','a)
#
#
# ---
#
#
# 7. What happens if an existing file is opened in write mode?
#
# Answer:
#
# It will overide the existing file and start from the scratch
#
#
#
#
# ---
#
#
# 8. How do you tell the difference between read() and readlines()?
#
# Answer;
#
# read(): this function would treat each character in the file sperately, meaning that the itertion would happen for every character.
#
# readline()-->this function reads single line of the file.
#
# ---
#
#
# 9. What data structure does a shelf value resemble?
#
# The shelf value resemble dictionary data structure.
