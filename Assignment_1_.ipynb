# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushanth172308/python_basic_assignments_theory/blob/main/Assignment_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <b> 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
#
#
#
#
# /
#
# 6
# </b>
#
#
# ANSWER:
#
# Values are  : 'hello',-87.8,6
#
# Expressions are  : * ,- ,/
#
# ---
#
# <b>2. What is the difference between string and variable?</b>
#
# String is a type of information you would store in a Variable
#
# A Variable is a store of information
#
#
#
# ---
# <b>3. Describe three different data types.</b>
# 1. Integers
# 2.Floating-point Nubers
# 3.Boolean
#
#
# ---
# <b>4. What is an expression made up of? What do all expressions do? </b>
#
# An expression is a combination of values,variaables,operators and calls to functions.
# An expression always evaluates down to a single value.
#
# ---
#
# <b>5.This assignment statements, like spam = 10. What is the difference between an expression and a statement? </b>
#
# An expression is any section of the code that evaluates to a value,while a statement is a complete line of code that performs some action.
#
# ---
# <b>6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1 </b>
#
# 23
#
# ---
# <b>7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3 </b>
#
# Restuls the same
#
# 'spam' + 'spamspam' = 'spamspamspam'
#
# 'spam' * 3 = 'spamspamspam'
#
# ---
# <b>8. Why is eggs a valid variable name while 100 is invalid?</b>
#   Becasue variable names can't begin with nubers on the other hand eggs is vaild variable
#
# ---
#
# <b>9. What three functions can be used to get the integer, floating-point number, or string version of a value?</b>
#
# The three functions that can be used are:
#
# int(),
# float(),
# str()
#
# ---
# <b> 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'</b>
#
#
# Because concatenation is only possible between the strings but here we are trying to add an integer.
#
# by turning the  '99'  to string we can fix this issue.
#
#
# 'I have eaten ' + '99' + ' burritos.'
#
# RESULT:
# I have eaten 99 burritos.
