# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushanth172308/python_basic_assignments_theory/blob/main/Assignment_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?
#
# Answer:
#
# The pdfFileReader()--> needs to be opened in read -binary mode by passing 'rb' as the second argument to open()
#
# The pdfFileWriter()--> needs to be opened in write -binary mode by passing 'wb' as the second argument to open()
#
# ---
#
#
# 2. From a PdfFileReader object, how do you get a Page object for page 5?
#
# Answer:
# You can get a Page object by calling the getPage(4) method
#
#  pdfReader.getPage(4)
#
#
#
#
# ---
#
#
# 3. What PdfFileReader variable stores the number of pages in the PDF document?
#
# Answer:
#
# The total number of pages in the document is stored in the numPages attribute of a PdfFileReader object
#
#
#
#
# ---
#
#
# 4. If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do before you can obtain Page objects from it?
#
# Answer:
# we need to decrypt like as follows.
#
# pdfReader.decrypt('swordfish')
#
#
#
#
#
#
# ---
#
#
# 5. What methods do you use to rotate a page?
#
# Answer:
#
# page.rotateClockwise(90)
# page.rotateCounterClockwise()
#
# Pass one of the integers 90, 180, or 270 to these methods
#
#
#
#
#
# ---
#
#
# 6. What is the difference between a Run object and a Paragraph object?
#
# Answer:For word documents
#
# Character styles can be applied to Run objects
#
# paragraph styles can be applied to paragraph objects.
#
#
#
#
#
#
# ---
#
#
# 7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable named doc?
#
# Answer:
#
# Use doc.paragraphs
#
#
# ---
#
#
# 8. What type of object has bold, underline, italic, strike, and outline variables?
#
# Answer:
#
# Run objects
#
#
#
#
#
#
# ---
#
#
# 9. What is the difference between False, True, and None for the bold variable?
#
# Answer:
# False: In this case the attribue is always disabled
#
# true:  In this case the attribute is always enabled , no matter what ohter styles are applied to the run.
#
#
#
# None: Defaults to whateever the run's style is set to.
#
#
#
# ---
#
#
# 10. How do you create a Document object for a new Word document?
#
# Answer:
# we can create the a Document object by the following way:
#
#
# import docx
# docx.Document()
#
#
# ---
#
#
# 11. How do you add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named doc?
#
# Answer:
# import docx
# doc = docx.Document()
# doc = doc.add_paragraph('Hello there)'
#
#
#
#
# ---
#
#
# 12. What integers represent the levels of headings available in Word documents?
#
# Answer:
#
# The integers are: 0,1,2,3,4
