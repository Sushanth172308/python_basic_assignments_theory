# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushanth172308/python_basic_assignments_theory/blob/main/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1 . What exactly is []?
#
# Answer:
#
# square brackets,represteation of one of python datastructures that is List.
#
#
# ---
# 2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.) Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.
#
# Answer:
#
# spam[2] = 'hello'
#
#
# ---
#
# 3. What is the value of spam[int(int('3' * 2) / 11)]?
#
# Answer:8
#
#
#
# ---
# 4. What is the value of spam[-1]?
#
# Answer:['a', 'b', 'c', 'd']
#
#
#
# ---
#
# 5.What is the value of spam[:2]? Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.
#
# answer:[2,4]
#
#
#
# ---
#
# 6.What is the value of bacon.index('cat')?
#
# Answer:1
#
#
#
# ---
#
# 7.How does bacon.append(99) change the look of the list value in bacon?
#
# answer:
#
# [3.14, 'cat', 11, 'cat', True, 99]
#
#
#
# ---
# 8.How does bacon.remove('cat') change the look of the list in bacon?
#
# answer:
#
# [3.14, 11, 'cat', True, 99]
#
#
# ---
#
# 9.What are the list concatenation and list replication operators?
#
# Answer:
#
# Concatenation operator is :  <b>+</b>
#
# Replication operator is : <b> * </b>
#
#
#
# ---
#
# 10. What is difference between the list methods append() and insert()?
#
# Answer:
#
# append()  : Adds the element at the end of the list
#
# Insert()  :  we can add  element where ever we want, it takes two arguemnts, we can specify index position and value.
#
# ---
#
# 11.What are the two methods for removing items from a list?
#
# Answer:
#
# The methods are:  remove() and pop()
#
#
#
# ---
#
# 12.Describe how list values and string values are identical.
#
# Answer:
#
# When we represent stirngs values  in list we  use '' to denote strings.
#
# if we represent a string we do the same thing, that is we use '' to denote string.
#
# List representation:
#
# Example = list = ['computer',12,'iphone']
#
# string representation:
#
# s = 'computer'
#
#
#
# ---
#
# 13.What's the difference between tuples and lists?
#
# Answwer:
#
#
# The main defferece is:
# Lists are mutable whereas tuples are immutable
#
#
#
# ---
#
# 14. How do you type a tuple value that only contains the integer 42?
#
# Answer:
#
# tuple = (0,42)
#
# ---
#
# 15.How do you get a list value's tuple form? How do you get a tuple value's list form?
#
# Answer:
#
# By using Typecasting
#
#
# 16 .Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?
#
# Answer:
#
# Variable that contain list values can be data types such as int,float,boolean or string, or can be a sequence of lists,tuples or collection of set or dictionary.
#
#
# ---
# 17.How do you distinguish between copy.copy() and copy.deepcopy()?
#
# Answer:
#
#  copy.copy(): A shallow copy constructs a new compound object and then (to the extent possible) inserts references into it to the objects found in the original.
#
# copy.deepcopy(): A deep copy constructs a new compound object and then, recursively, inserts copies into it of the objects found in the original.

# %%
tuplex =tuple 42 
type(t)
# Out:
#   File "<ipython-input-13-cb6034cb170b>", line 1
#     tuplex =tuple 42
#                    ^
# SyntaxError: invalid syntax
